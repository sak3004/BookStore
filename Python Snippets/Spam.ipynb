# %%
s = open('sample.txt').read()
map(len, s.split())

list(map(len, s.split()))
# Out:
# [6,
#  6,
#  12,
#  5,
#  2,
#  3,
#  7,
#  2,
#  9,
#  3,
#  6,
#  10,
#  2,
#  1,
#  7,
#  2,
#  1,
#  3,
#  4,
#  2,
#  1,
#  3,
#  6,
#  8,
#  6,
#  13,
#  8,
#  2,
#  2,
#  10,
#  10,
#  2,
#  8,
#  8,
#  2,
#  8,
#  3,
#  7,
#  3,
#  6,
#  6,
#  2,
#  3,
#  6,
#  7,
#  6,
#  3,
#  4,
#  10,
#  1,
#  7,
#  7,
#  2,
#  3,
#  6,
#  7,
#  5,
#  3,
#  4,
#  8,
#  2,
#  4,
#  7,
#  4,
#  3,
#  6,
#  8,
#  6,
#  5,
#  8,
#  3,
#  4,
#  2,
#  9,
#  4,
#  13,
#  3,
#  3,
#  6,
#  9,
#  5,
#  2,
#  7,
#  9,
#  5,
#  7,
#  5,
#  7,
#  8,
#  10,
#  4,
#  7,
#  3,
#  17,
#  8,
#  6,
#  8,
#  3,
#  7,
#  4,
#  5,
#  6,
#  6,
#  12,
#  2,
#  4,
#  3,
#  6,
#  2,
#  7,
#  2,
#  10,
#  1,
#  9,
#  6,
#  8,
#  2,
#  4,
#  3,
#  3,
#  5,
#  4,
#  2,
#  9,
#  2,
#  6,
#  7,
#  4,
#  1,
#  4,
#  6,
#  1,
#  5,
#  6,
#  3,
#  3,
#  8,
#  2,
#  9,
#  3,
#  6,
#  7,
#  2,
#  4,
#  7,
#  2,
#  8,
#  2,
#  13,
#  9,
#  2,
#  2,
#  8,
#  9,
#  9,
#  3,
#  9,
#  3,
#  6,
#  7,
#  5,
#  3,
#  8,
#  10,
# ...
